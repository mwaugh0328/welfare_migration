# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import scipy.io
import seaborn as sns

# %%
move_mat = scipy.io.loadmat( "movepolicy_exp.mat")

low_move_expr = pd.DataFrame(move_mat["lowz_expr"])

med_move_expr = pd.DataFrame(move_mat["medz_expr"])

exp_move_expr = pd.DataFrame(move_mat["lowz_exp_expr"]) 

move_mat = scipy.io.loadmat( "movepolicy.mat")

low_move = pd.DataFrame(move_mat["lowz"])

med_move = pd.DataFrame(move_mat["medz"])

exp_move = pd.DataFrame(move_mat["lowz_exp"])

# %% [markdown]
# ### Migration Decision

# %%
fig, ax = plt.subplots(1,1,figsize = (16,10))

#cbar_ax = fig.add_axes([0.95, .25, .03, .5])

sns.heatmap( ((1-low_move).iloc[50:100,0:5] ), cmap="Blues",cbar = True, vmin=0,vmax=1.0, ax=ax,
            cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"),
            alpha = 0.75)

#sns.heatmap((1-low_move_expr).iloc[50:100,0:30], cmap="Reds",cbar = True, vmin=0, 
 #          cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"),
  #          vmax=1.0, ax=ax, alpha = 0.45)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax.text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax.text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

ax.set_title("Migration Policy Function: Low z, No Experience \n", fontsize = 16)

fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

#plt.savefig("migration_policy_low_z.png", bbox_inches = "tight")

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (16,10))

#cbar_ax = fig.add_axes([0.95, .25, .03, .5])

sns.heatmap( ((1-low_move_expr).iloc[50:100,0:30] - (1-low_move).iloc[50:100,0:30] ), cmap="Blues", cbar = True, vmin=0,vmax=1.0, ax=ax,
            cbar_kws=dict(use_gridspec=False,location="right",label = "\n Δ Probability of Moving"),
            alpha = 0.75)

#sns.heatmap((1-low_move_expr).iloc[50:100,0:30], cmap="Reds",cbar = True, vmin=0, 
 #          cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"),
  #          vmax=1.0, ax=ax, alpha = 0.45)

ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax.text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax.text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

ax.set_title("Migration Policy Function: Low z, No Experience \n", fontsize = 16)

fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

#plt.savefig("migration_policy_low_z.png", bbox_inches = "tight")

plt.show()

# %%
#fig, ax = plt.subplots(1,1,figsize = (16,10))

#cbar_ax = fig.add_axes([0.95, .25, .03, .5])

#sns.heatmap((1-low_move).iloc[50:100,0:30], cmap="Blues",cbar = False, vmin=0,vmax=1.0, ax=ax,
#            alpha = 0.95)

#sns.heatmap(((1-low_move_expr).iloc[50:100,0:30] - (1-low_move).iloc[50:100,0:30] ), cmap="Reds",cbar = True, vmin=0, 
#           cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"),
#            vmax=1.0, ax=ax, alpha = 0.75)

#ax.get_xaxis().set_visible(False)
#ax.get_yaxis().set_visible(False)

#ax.text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

#ax.text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

#ax.set_title("CCT (RED), Status quo (Blue) Migration Policy Function: Low z, No Experience \n", fontsize = 16)

#fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

#plt.savefig("migration_policy_low_z.png", bbox_inches = "tight")

#plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize = (16,10))

cbar_ax = fig.add_axes([.93, .15, .03, 0.70])

sns.heatmap((1-low_move).iloc[50:100,0:30], cmap="Blues",cbar = False,vmin=0,vmax=1.0, ax=ax[0], alpha = 0.90)

sns.heatmap((1-low_move_expr).iloc[50:100,0:30], cmap="Blues",cbar = True,vmin=0,vmax=1.0, ax=ax[1],
            cbar_kws={'label': '\n Probability of Moving'}, 
             cbar_ax = cbar_ax, alpha = 0.90)

label_list = ["Status Quo", "Conditional Cash Transfer"]

count = 0

for xxx in ax:
    
    xxx.get_xaxis().set_visible(False)
    xxx.get_yaxis().set_visible(False)
    
    xxx.set_title(label_list[count])
    
    count = count + 1

ax[0].text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax[0].text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

fig.suptitle("Migration Policy Function: Low z, No Experience \n", fontsize = 16)

#fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

plt.savefig("migration_policy_low_z_both.png", bbox_inches = "tight")

plt.show()

# %%
fig, ax = plt.subplots(2,2,figsize = (10,7))

ax = ax.ravel()

cbar_ax = fig.add_axes([0.95, .25, .03, .5])

sns.heatmap(rot_df(grp.get_group(0.7655825075433658)), cmap="Blues",cbar = False,vmin=0,vmax=0.30, ax=ax[0])

sns.heatmap(rot_df(grp.get_group(0.8918304295121527)), cmap="Blues",cbar = False,vmin=0,vmax=0.30, ax=ax[1])

sns.heatmap(rot_df(grp.get_group(1.1212893919161493)), cmap="Blues",cbar = False,vmin=0,vmax=0.30, ax=ax[2])

sns.heatmap(rot_df(grp.get_group(1.3061949432580993)), cmap="Blues",cbar = True, vmin=0,vmax=0.30,
            cbar_kws={'label': '\n Probability of Moving'}, cbar_ax = cbar_ax, ax=ax[3])

label_list = ["Low Z", "Medium Low Z", "Medium High Z", "High Z"]

count = 0

for xxx in ax:
    
    xxx.get_xaxis().set_visible(False)
    xxx.get_yaxis().set_visible(False)
    
    xxx.set_title(label_list[count])
    
    count = count + 1


ax[2].text(-1, 2.25, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax[2].text(0, 60.25, "Less Import Exposure ⟶ ",fontsize = 14)

fig.suptitle("Migration Policy Functions \n", fontsize = 16)

plt.savefig(fig_path + "\\migration_policy_new.pdf", bbox_inches = "tight", dip = 3600)

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (16,9))

#cbar_ax = fig.add_axes([0.95, .25, .03, .5])

sns.heatmap((1-med_move).iloc[50:100,0:30], cmap="Blues",cbar = True,vmin=0,vmax=1.0, ax=ax,
           cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax.text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax.text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

ax.set_title("Migration Policy Function: Moderate z, No Experince \n", fontsize = 16)

fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

plt.savefig(fig_path + "\\migration_policy_mod_z.pdf", bbox_inches = "tight", dip = 3600)

plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize = (16,10))

cbar_ax = fig.add_axes([.93, .15, .03, 0.70])

sns.heatmap((1-med_move).iloc[50:100,0:30], cmap="Blues",cbar = False,vmin=0,vmax=1.0, ax=ax[0], alpha = 0.90)

sns.heatmap((1-med_move_expr).iloc[50:100,0:30], cmap="Blues",cbar = True,vmin=0,vmax=1.0, ax=ax[1],
            cbar_kws={'label': '\n Probability of Moving'}, 
             cbar_ax = cbar_ax, alpha = 0.90)

label_list = ["Status Quo", "Conditional Cash Transfer"]

count = 0

for xxx in ax:
    
    xxx.get_xaxis().set_visible(False)
    xxx.get_yaxis().set_visible(False)
    
    xxx.set_title(label_list[count])
    
    count = count + 1

ax[0].text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax[0].text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

fig.suptitle("Migration Policy Function: Med z, No Experience \n", fontsize = 16)

#fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

plt.savefig("migration_policy_med_z_both.png", bbox_inches = "tight")

plt.show()

# %%
fig, ax = plt.subplots(1,1,figsize = (16,9))

#cbar_ax = fig.add_axes([0.95, .25, .03, .5])

sns.heatmap((1-exp_move).iloc[50:100,0:30], cmap="Blues",cbar = True,vmin=0,vmax=1.00, ax=ax,
           cbar_kws=dict(use_gridspec=False,location="right",label = "\n Probability of Moving"))
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax.text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax.text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

ax.set_title("Migration Policy Function: Low z, Experince \n", fontsize = 16)

fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

plt.savefig(fig_path + "\\migration_policy_exp_z.pdf", bbox_inches = "tight", dip = 3600)

plt.show()

# %%
fig, ax = plt.subplots(1,2,figsize = (16,10))

cbar_ax = fig.add_axes([.93, .15, .03, 0.70])

sns.heatmap((1-exp_move).iloc[50:100,0:30], cmap="Blues",cbar = False,vmin=0,vmax=1.0, ax=ax[0], alpha = 0.90)

sns.heatmap((1-exp_move_expr).iloc[50:100,0:30], cmap="Blues",cbar = True,vmin=0,vmax=1.0, ax=ax[1],
            cbar_kws={'label': '\n Probability of Moving'}, 
             cbar_ax = cbar_ax, alpha = 0.90)

label_list = ["Status Quo", "Conditional Cash Transfer"]

count = 0

for xxx in ax:
    
    xxx.get_xaxis().set_visible(False)
    xxx.get_yaxis().set_visible(False)
    
    xxx.set_title(label_list[count])
    
    count = count + 1

ax[0].text(-2, 50, "Larger Asset Holdings ⟶ ",fontsize = 14, rotation = 90)

ax[0].text(0, 53, "Larger Transitory Shock ⟶ ",fontsize = 14)

fig.suptitle("Migration Policy Function: Low z, Experience \n", fontsize = 16)

#fig_path = "C:\\github\\welfare_migration\\slides\\TALK-FIGURES\\"

plt.savefig("migration_policy_low_z_exp_both.png", bbox_inches = "tight")

plt.show()
